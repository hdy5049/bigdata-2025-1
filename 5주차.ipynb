# %%
import requests

# %%
url = 'http://openapi.seoul.go.kr:8088/4b7a74714968647939304e4b674747/json/SebcCollegeInfoKor/1/100/'
r = requests.get(url)

# %%
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<RESULT>\n<CODE>ERROR-301</CODE>\n<MESSAGE>\xed\x8c\x8c\xec\x9d\xbc\xed\x83\x80\xec\x9e\x85 \xea\xb0\x92\xec\x9d\xb4 \xeb\x88\x84\xeb\x9d\xbd \xed\x98\xb9\xec\x9d\x80 \xec\x9c\xa0\xed\x9a\xa8\xed\x95\x98\xec\xa7\x80 \xec\x95\x8a\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4.\n\xec\x9a\x94\xec\xb2\xad\xec\x9d\xb8\xec\x9e\x90 \xec\xa4\x91 TYPE\xec\x9d\x84 \xed\x99\x95\xec\x9d\xb8\xed\x95\x98\xec\x8b\xad\xec\x8b\x9c\xec\x98\xa4.</MESSAGE>\n</RESULT>\n'

# %%
data = r.json()
data
# Out:
# {'SebcCollegeInfoKor': {'list_total_count': 64,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'MAIN_KEY': 'BE_LiST23-0034',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '서울시립대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '공립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 동대문구 서울시립대로 163 (전농동 90번지) ',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '동대문구',
#     'H_KOR_DONG': '휘경2동',
#     'TEL': '02-6490-6114',
#     'FAX': '02-2210-5576',
#     'HP': 'http://www.uos.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0035',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(3년제)',
#     'NAME_KOR': '서울여자간호대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서대문구 홍제3동 서울여자간호대학',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '홍제2동',
#     'TEL': '02-2287-1700',
#     'FAX': '02-395-8018',
# ...

# %%
import pandas as pd

# %%
temp =[]
for d in data['SebcCollegeInfoKor']['row']:
    temp.append(d)
uri = pd.DataFrame(temp)
uri
# Out:
#           MAIN_KEY  YEAR CATE1_NAME   NAME_KOR BRANCH   STATE   TYPE POSTCODE  \
# 0   BE_LiST23-0034  2013       일반대학    서울시립대학교     본교      기존     공립
# 1   BE_LiST23-0035  2013  전문대학(3년제)  서울여자간호대학교     본교      기존     사립
# 2   BE_LiST23-0036  2013       일반대학    서울여자대학교     본교      기존     사립
# 3   BE_LiST23-0037  2013  전문대학(2년제)      서일대학교     본교  학교명 변경     사립
# 4   BE_LiST23-0038  2013       일반대학     성공회대학교     본교      기존     사립
# ..             ...   ...        ...        ...    ...     ...    ...      ...
# 59  BE_LiST23-0029  2013       교육대학    서울교육대학교     본교      기존     국립
# 60  BE_LiST23-0030  2013       일반대학    서울기독대학교     본교      기존     사립
# 61  BE_LiST23-0031  2013       일반대학      서울대학교     본교      기존  국립대법인
# 62  BE_LiST23-0032  2013  사이버대학(대학)   서울디지털대학교     본교      기존     사립
# 63  BE_LiST23-0033  2013  사이버대학(대학)   서울사이버대학교     본교      기존     사립
#
#                                   ADD_KOR ADD_KOR_ROAD H_KOR_CITY H_KOR_GU  \
# ...

# %%
url = 'http://openapi.seoul.go.kr:8088/4b7a74714968647939304e4b674747/json/TbParkingInfoView/1/100/'
r = requests.get(url)

# %%
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<RESULT>\n<CODE>ERROR-301</CODE>\n<MESSAGE>\xed\x8c\x8c\xec\x9d\xbc\xed\x83\x80\xec\x9e\x85 \xea\xb0\x92\xec\x9d\xb4 \xeb\x88\x84\xeb\x9d\xbd \xed\x98\xb9\xec\x9d\x80 \xec\x9c\xa0\xed\x9a\xa8\xed\x95\x98\xec\xa7\x80 \xec\x95\x8a\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4.\n\xec\x9a\x94\xec\xb2\xad\xec\x9d\xb8\xec\x9e\x90 \xec\xa4\x91 TYPE\xec\x9d\x84 \xed\x99\x95\xec\x9d\xb8\xed\x95\x98\xec\x8b\xad\xec\x8b\x9c\xec\x98\xa4.</MESSAGE>\n</RESULT>\n'

# %%
data = r.json()
data
# Out:
# {'TbParkingInfoView': {'list_total_count': 29,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'DSTRCT_TYPE': '강서',
#     'PKLT_TYPE': '강서1주차장',
#     'PSTN_INFO_LAT': '37.585709',
#     'PSTN_INFO_LOT': '126.818279',
#     'ADDR': '서울강서구방화동61(방화동)',
#     'PRK_CNT': 53.0,
#     'PWDBS_PRK_CNT': 0.0,
#     'PRD_PRK_CNT': 0.0,
#     'WD_OPER_BGNG_TM': '06:00',
#     'WD_OPER_END_TM': '23:00',
#     'WE_OPER_BGNG_TM': '06:00',
#     'WE_OPER_END_TM': '23:00',
#     'EXMPTN_HR': 10.0,
#     'BSC_HR': 30.0,
#     'BSC_CRG': 1000.0,
#     'INTR_HR': 10.0,
#     'INTR_CRG': 200.0,
#     'PRVDY_CRG': 10000.0,
#     'WKLY_CRG': 0.0,
#     'NGHT_CRG': 0.0,
#     'PRD_AMT': 50000.0,
#     'PKLT_OPER_BZENTY': '공우이엔씨(주)_양화_강서',
#     'BZENTY_TEL': '02-2068-9617',
#     'OPER_BGNG_PRD': '2023-12-01 00:00:00.0',
#     'OPER_END_PRD': '2025-11-30 00:00:00.0'},
#    {'DSTRCT_TYPE': '광나루',
#     'PKLT_TYPE': '광나루1,2주차장',
#     'PSTN_INFO_LAT': '37.553885',
# ...

# %%
temp =[]
for d in data['TbParkingInfoView']['row']:
    temp.append(d)
uri = pd.DataFrame(temp)
uri
# Out:
#    DSTRCT_TYPE   PKLT_TYPE     PSTN_INFO_LAT     PSTN_INFO_LOT  \
# 0           강서      강서1주차장         37.585709        126.818279
# 1          광나루   광나루1,2주차장         37.553885         127.12316
# 2          광나루     광나루3주차장         37.543078        127.117775
# 3           난지  난지1,2,3주차장       37.56982189       126.8736403
# 4           뚝섬      뚝섬1주차장        37.5276908       127.0781632
# 5           뚝섬      뚝섬2주차장        37.5290757       127.0735242
# 6           뚝섬      뚝섬3주차장        37.5306712       127.0673524
# 7           뚝섬      뚝섬4주차장        37.5314716       127.0644017
# 8           망원      망원1주차장        37.5444625        126.911188
# 9           망원    망원2,3주차장        37.5499925       126.9022723
# 10          망원      망원4주차장        37.5564177       126.8940296
# 11          반포      반포1주차장        37.5135907       127.0032551
# 12          반포    반포2,3주차장        37.5100713       126.9958898
# 13          양화      양화1주차장        37.5373673        126.903686
# ...

# %%
import folium

# %%
folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
anMap = folium.Map(location=[37.5276908,127.0781632 ],
                   zoom_start=12,
                   zoom_control=False,
                   control_scale= True)
anMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium.plugins import MarkerCluster
mc = MarkerCluster().add_to(anMap)

for n, row in uri.iterrows():
  folium.Marker(location=[row['PSTN_INFO_LAT'], row['PSTN_INFO_LOT']],
                popup= folium.Popup(row['PKLT_TYPE'], max_width=200)
                ).add_to(mc)


anMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
